# %% [markdown]
# ## In this exercise, we will use the HR dataset and understand the following:
#
# > 1. Building the logistic regression model
# 2. Writing the model equation and interpreting the model summary
# 3. Creating the Confusion Matrix
# 4. Using mis-classification cost as a criteria to select the best cut-off
# 5. Using Younden Index as the criteria to select the best cut-off
# 6. Creating the Confusion Matrix and ROC plot on test data
# 9. Changing the base or reference category and evaluate the impact on the model (This is self work/assignment)
# 10. Change the cut-off value using model 1 (This is self work/assignment)
#
# ***
#
# # Code starts here
#
# To know the environment with the pyhton kernal

# %%
import sys, os

sys.executable
# Out:
# '/Users/Rahul/anaconda3/bin/python'

# %% [markdown]
# We are going to use below mentioned libraries for **data import, processing and visulization**. As we progress, we will use other specific libraries for model building and evaluation.

# %%
import pandas as pd 
import numpy as np
import seaborn as sn # visualization library based on matplotlib
import matplotlib.pylab as plt

#the output of plotting commands is displayed inline within frontends like in Jupyter notebook
# %matplotlib inline

# %% [markdown]
# ## Data Import and Manipulation
#
# ### 1. Importing a data set
#
# _Give the correct path to the data_

# %% [markdown]
# modify the ast_note_interactivity kernel option to see the value of multiple statements at once.

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
#raw.data <- read.csv("/Users/Rahul/Documents/Datasets/IMB533_HR_Data_No_Missing_Value.csv", 
#                     header = TRUE,sep = ",",na.strings = c(""," ", "NA"))


raw_df = pd.read_csv( "/Users/Rahul/Documents/Datasets/IMB533_HR_Data_No_Missing_Value.csv", 
                        sep = ',', na_values = ['', ' '])

raw_df.columns = raw_df.columns.str.lower().str.replace(' ', '_')
raw_df.head()
# Out:
#    slno  candidate_ref doj_extended  duration_to_accept_offer  notice_period  \
# 0     1        2110407          Yes                        14             30
# 1     2        2112635           No                        18             30
# 2     3        2112838           No                         3             45
# 3     4        2115021           No                        26             30
# 4     5        2115125          Yes                         1            120
#
#   offered_band  pecent_hike_expected_in_ctc  percent_hike_offered_in_ctc  \
# 0           E2                       -20.79                        13.16
# 1           E2                        50.00                       320.00
# 2           E2                        42.84                        42.84
# 3           E2                        42.84                        42.84
# 4           E2                        42.59                        42.59
#
#    percent_difference_ctc joining_bonus candidate_relocate_actual  gender  \
# 0                   42.86            No                        No  Female
# 1                  180.00            No                        No    Male
# 2                    0.00            No                        No    Male
# 3                    0.00            No                        No    Male
# 4                    0.00            No                       Yes    Male
#
#     candidate_source  rex_in_yrs    lob location  age  status
# 0             Agency           7    ERS    Noida   34  Joined
# 1  Employee Referral           8  INFRA  Chennai   34  Joined
# 2             Agency           4  INFRA    Noida   27  Joined
# 3  Employee Referral           4  INFRA    Noida   34  Joined
# 4  Employee Referral           6  INFRA    Noida   34  Joined

# %%
#?pd.read_csv

# %% [markdown]
# Dropping SLNo and Candidate.Ref as these will not be used for any analysis or model building.

# %%
#?raw_df.drop()

# %%
if set(['slno','candidate_ref']).issubset(raw_df.columns):
    raw_df.drop(['slno','candidate_ref'],axis=1, inplace=True)
    
raw_df.head()
# Out:
#   doj_extended  duration_to_accept_offer  notice_period offered_band  \
# 0          Yes                        14             30           E2
# 1           No                        18             30           E2
# 2           No                         3             45           E2
# 3           No                        26             30           E2
# 4          Yes                         1            120           E2
#
#    pecent_hike_expected_in_ctc  percent_hike_offered_in_ctc  \
# 0                       -20.79                        13.16
# 1                        50.00                       320.00
# 2                        42.84                        42.84
# 3                        42.84                        42.84
# 4                        42.59                        42.59
#
#    percent_difference_ctc joining_bonus candidate_relocate_actual  gender  \
# 0                   42.86            No                        No  Female
# 1                  180.00            No                        No    Male
# 2                    0.00            No                        No    Male
# 3                    0.00            No                        No    Male
# 4                    0.00            No                       Yes    Male
#
#     candidate_source  rex_in_yrs    lob location  age  status
# 0             Agency           7    ERS    Noida   34  Joined
# 1  Employee Referral           8  INFRA  Chennai   34  Joined
# 2             Agency           4  INFRA    Noida   27  Joined
# 3  Employee Referral           4  INFRA    Noida   34  Joined
# 4  Employee Referral           6  INFRA    Noida   34  Joined

# %% [markdown]
# ### 2. Structure of the dataset

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8995 entries, 0 to 8994
# Data columns (total 16 columns):
# doj_extended                   8995 non-null object
# duration_to_accept_offer       8995 non-null int64
# notice_period                  8995 non-null int64
# offered_band                   8995 non-null object
# pecent_hike_expected_in_ctc    8995 non-null float64
# percent_hike_offered_in_ctc    8995 non-null float64
# percent_difference_ctc         8995 non-null float64
# joining_bonus                  8995 non-null object
# candidate_relocate_actual      8995 non-null object
# gender                         8995 non-null object
# candidate_source               8995 non-null object
# rex_in_yrs                     8995 non-null int64
# lob                            8995 non-null object
# location                       8995 non-null object
# age                            8995 non-null int64
# status                         8995 non-null object
# dtypes: float64(3), int64(4), object(9)
# memory usage: 1.1+ MB

# %%
raw_df.status.value_counts()
raw_df.describe(include='all').transpose()
# Out:
# Joined        7313
# Not Joined    1682
# Name: status, dtype: int64
#                             count unique      top  freq     mean      std  \
# doj_extended                 8995      2       No  4788      NaN      NaN
# duration_to_accept_offer     8995    NaN      NaN   NaN  21.4345  25.8116
# notice_period                8995    NaN      NaN   NaN  39.2918  22.2202
# offered_band                 8995      4       E1  5568      NaN      NaN
# pecent_hike_expected_in_ctc  8995    NaN      NaN   NaN  43.8648   29.789
# percent_hike_offered_in_ctc  8995    NaN      NaN   NaN  40.6574  36.0641
# percent_difference_ctc       8995    NaN      NaN   NaN  -1.5738  19.6107
# joining_bonus                8995      2       No  8578      NaN      NaN
# candidate_relocate_actual    8995      2       No  7705      NaN      NaN
# gender                       8995      2     Male  7444      NaN      NaN
# candidate_source             8995      3   Direct  4801      NaN      NaN
# rex_in_yrs                   8995    NaN      NaN   NaN  4.23902  2.54757
# lob                          8995      9    INFRA  2850      NaN      NaN
# location                     8995     11  Chennai  3150      NaN      NaN
# age                          8995    NaN      NaN   NaN  29.9132  4.09791
# status                       8995      2   Joined  7313      NaN      NaN
#
#                                min    25%  50%    75%     max
# doj_extended                   NaN    NaN  NaN    NaN     NaN
# duration_to_accept_offer         0      3   10     33     224
# notice_period                    0     30   30     60     120
# offered_band                   NaN    NaN  NaN    NaN     NaN
# pecent_hike_expected_in_ctc -68.83  27.27   40  53.85  359.77
# percent_hike_offered_in_ctc -60.53  22.09   36     50  471.43
# percent_difference_ctc      -67.27  -8.33    0      0     300
# joining_bonus                  NaN    NaN  NaN    NaN     NaN
# candidate_relocate_actual      NaN    NaN  NaN    NaN     NaN
# gender                         NaN    NaN  NaN    NaN     NaN
# candidate_source               NaN    NaN  NaN    NaN     NaN
# rex_in_yrs                       0      3    4      6      24
# lob                            NaN    NaN  NaN    NaN     NaN
# location                       NaN    NaN  NaN    NaN     NaN
# age                             20     27   29     34      60
# status                         NaN    NaN  NaN    NaN     NaN

# %% [markdown]
# To get a help on the features of a object

# %%
#?raw_df.status.value_counts()

# %% [markdown]
# ### 2. Summarizing the dataset
# Create a new data frame and store the raw data copy. This is being done to have a copy of the raw data intact for further manipulation if needed. The *dropna()* function is used for row wise deletion of missing value. The axis = 0 means row-wise, 1 means column wise.

# %%
filter_df = raw_df.dropna(axis=0, how='any', thresh=None, 
                             subset=None, inplace=False)

list(filter_df.columns )
# Out:
# ['doj_extended',
#  'duration_to_accept_offer',
#  'notice_period',
#  'offered_band',
#  'pecent_hike_expected_in_ctc',
#  'percent_hike_offered_in_ctc',
#  'percent_difference_ctc',
#  'joining_bonus',
#  'candidate_relocate_actual',
#  'gender',
#  'candidate_source',
#  'rex_in_yrs',
#  'lob',
#  'location',
#  'age',
#  'status']

# %%
#?raw_df.dropna

# %% [markdown]
# We will first start by printing the unique labels in categorical features

# %%
numerical_features = ['duration_to_accept_offer','notice_period','pecent_hike_expected_in_ctc',
                      'percent_hike_offered_in_ctc','percent_difference_ctc','rex_in_yrs','age']

categorical_features = ['doj_extended','offered_band','joining_bonus','candidate_relocate_actual',
                        'gender','candidate_source','lob','location','status']

for f in categorical_features:
    print("\nThe unique labels in {} is {}\n".format(f, filter_df[f].unique()))
    print("The values in {} is \n{}\n".format(f,  filter_df[f].value_counts()))
# Out:
# The unique labels in doj_extended is ['Yes' 'No']
#
# The values in doj_extended is
# No     4788
# Yes    4207
# Name: doj_extended, dtype: int64
#
#
# The unique labels in offered_band is ['E2' 'E1' 'E3' 'E0']
#
# The values in offered_band is
# E1    5568
# E2    2711
# E3     505
# E0     211
# Name: offered_band, dtype: int64
#
#
# The unique labels in joining_bonus is ['No' 'Yes']
#
# The values in joining_bonus is
# No     8578
# Yes     417
# Name: joining_bonus, dtype: int64
#
#
# The unique labels in candidate_relocate_actual is ['No' 'Yes']
#
# The values in candidate_relocate_actual is
# No     7705
# Yes    1290
# Name: candidate_relocate_actual, dtype: int64
#
#
# The unique labels in gender is ['Female' 'Male']
#
# The values in gender is
# Male      7444
# Female    1551
# Name: gender, dtype: int64
#
#
# The unique labels in candidate_source is ['Agency' 'Employee Referral' 'Direct']
#
# The values in candidate_source is
# Direct               4801
# Agency               2585
# Employee Referral    1609
# Name: candidate_source, dtype: int64
#
#
# The unique labels in lob is ['ERS' 'INFRA' 'Healthcare' 'BFSI' 'CSMP' 'ETS' 'AXON' 'EAS' 'MMS']
#
# The values in lob is
# INFRA         2850
# ERS           2426
# BFSI          1396
# ETS            691
# CSMP           579
# AXON           568
# EAS            346
# Healthcare     124
# MMS             15
# Name: lob, dtype: int64
#
#
# The unique labels in location is ['Noida' 'Chennai' 'Gurgaon' 'Bangalore' 'Hyderabad' 'Kolkata' 'Cochin'
#  'Pune' 'Others' 'Mumbai' 'Ahmedabad']
#
# The values in location is
# Chennai      3150
# Noida        2727
# Bangalore    2230
# Hyderabad     341
# Mumbai        197
# Gurgaon       146
# Kolkata       129
# Pune           48
# Others         13
# Cochin          8
# Ahmedabad       6
# Name: location, dtype: int64
#
#
# The unique labels in status is ['Joined' 'Not Joined']
#
# The values in status is
# Joined        7313
# Not Joined    1682
# Name: status, dtype: int64

# %% [markdown]
# Looking at the feature **line of business** it seems that *EAS, Healthcare and MMS* does not have enough observations and may be clubbed together

# %%
filter_df['lob']=np.where(filter_df['lob'] =='EAS', 'Others', filter_df['lob'])
filter_df['lob']=np.where(filter_df['lob'] =='Healthcare', 'Others', filter_df['lob'])
filter_df['lob']=np.where(filter_df['lob'] =='MMS', 'Others', filter_df['lob'])
filter_df.lob.value_counts()
# Out:
# INFRA     2850
# ERS       2426
# BFSI      1396
# ETS        691
# CSMP       579
# AXON       568
# Others     485
# Name: lob, dtype: int64

# %% [markdown]
# We will use **groupby** function of pandas to get deeper insights of the behaviour of people **Joining** or **Not Joining** the company. We will write a generic function to report the mean by any categorical variable.

# %%
def group_by (categorical_features):
    return filter_df.groupby(categorical_features).mean()

# %%
group_by("doj_extended")
group_by("status")
# Out:
#               duration_to_accept_offer  notice_period  \
# doj_extended
# No                           13.171261      36.381579
# Yes                          30.838840      42.603993
#
#               pecent_hike_expected_in_ctc  percent_hike_offered_in_ctc  \
# doj_extended
# No                              43.907550                    40.923223
# Yes                             43.816154                    40.354773
#
#               percent_difference_ctc  rex_in_yrs        age
# doj_extended
# No                         -1.443452    4.011696  29.699248
# Yes                        -1.722154    4.497742  30.156644
#             duration_to_accept_offer  notice_period  \
# status
# Joined                     20.624368      37.244633
# Not Joined                 24.956599      48.192628
#
#             pecent_hike_expected_in_ctc  percent_hike_offered_in_ctc  \
# status
# Joined                        43.860660                    41.133205
# Not Joined                    43.882818                    38.588460
#
#             percent_difference_ctc  rex_in_yrs        age
# status
# Joined                   -1.262036    4.192944  30.004102
# Not Joined               -2.929298    4.439358  29.517836

# %% [markdown]
# ### 3. Visualizing the Data
#
# Plot can be done using the
# > pandas methods
# > matplotlib
# > seaborn

# %%
def hist_plot(data, group_by, xlabel,ylabel):
    pd.crosstab(data,group_by).plot(kind='density')
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title('Plot')
    plt.grid(True)
    x1,x2,y1,y2 = plt.axis()
    plt.axis((x1,x2,y1,y2))
    plt.show()
    #plt.subplot(1, 2)

# %%
numerical_features_set = ['duration_to_accept_offer','notice_period','age']
categorical_features_set = ['offered_band','gender','status']

for c in categorical_features_set:
    for n in numerical_features_set:
        hist_plot(filter_df[n], filter_df[c], n,c)

# %%
sn.countplot(x="age", data=filter_df)
plt.show()

# %%
sn.violinplot(x="age", data=filter_df)

# Show the plot
plt.show()

# %% [markdown]
# ## Model Approach 1:  With dummy variable coding
#
# ### Dummy Variable coding
#
# Remove the response variable from the dataset¶

# %%
X_features = list(filter_df.columns)
X_features.remove('status')
X_features.remove('pecent_hike_expected_in_ctc')
X_features.remove('percent_hike_offered_in_ctc')
X_features.remove('candidate_relocate_actual')

# %%
X_features

# %%
categorical_features = ['doj_extended','offered_band','joining_bonus','gender','candidate_source','lob','location']

# %%
#for i in categorical_features:
 #   if filter_df.dtypes.name = 'category'
encoded_X_df = pd.get_dummies( filter_df[X_features], columns = categorical_features, drop_first = True )
encoded_Y_df = pd.get_dummies( filter_df['status'], drop_first=False)

# %%
encoded_Y_df.columns
# Out:
# Index(['Joined', 'Not Joined'], dtype='object')

# %%
#?pd.get_dummies

# %%
pd.options.display.max_columns = None
encoded_X_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8995 entries, 0 to 8994
# Data columns (total 31 columns):
# duration_to_accept_offer              8995 non-null int64
# notice_period                         8995 non-null int64
# percent_difference_ctc                8995 non-null float64
# rex_in_yrs                            8995 non-null int64
# age                                   8995 non-null int64
# doj_extended_Yes                      8995 non-null uint8
# offered_band_E1                       8995 non-null uint8
# offered_band_E2                       8995 non-null uint8
# offered_band_E3                       8995 non-null uint8
# joining_bonus_Yes                     8995 non-null uint8
# gender_Male                           8995 non-null uint8
# candidate_source_Direct               8995 non-null uint8
# candidate_source_Employee Referral    8995 non-null uint8
# lob_BFSI                              8995 non-null uint8
# lob_CSMP                              8995 non-null uint8
# lob_EAS                               8995 non-null uint8
# lob_ERS                               8995 non-null uint8
# lob_ETS                               8995 non-null uint8
# lob_Healthcare                        8995 non-null uint8
# lob_INFRA                             8995 non-null uint8
# lob_MMS                               8995 non-null uint8
# location_Bangalore                    8995 non-null uint8
# location_Chennai                      8995 non-null uint8
# location_Cochin                       8995 non-null uint8
# location_Gurgaon                      8995 non-null uint8
# location_Hyderabad                    8995 non-null uint8
# location_Kolkata                      8995 non-null uint8
# location_Mumbai                       8995 non-null uint8
# location_Noida                        8995 non-null uint8
# location_Others                       8995 non-null uint8
# location_Pune                         8995 non-null uint8
# dtypes: float64(1), int64(4), uint8(26)
# memory usage: 650.0 KB

# %%
Y = encoded_Y_df.filter(['Joined'], axis =1)
X = encoded_X_df
Y.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8995 entries, 0 to 8994
# Data columns (total 1 columns):
# Joined    8995 non-null uint8
# dtypes: uint8(1)
# memory usage: 79.1 KB

# %% [markdown]
# ### Correlation amongst variable

# %%
X.corr()
#sb.heatmap(X.corr())  
#
# Out:
#                                     duration_to_accept_offer  notice_period  \
# duration_to_accept_offer                            1.000000       0.363760
# notice_period                                       0.363760       1.000000
# percent_difference_ctc                             -0.009395      -0.015067
# rex_in_yrs                                          0.113951       0.181786
# age                                                 0.020131      -0.004967
# doj_extended_Yes                                    0.341545       0.139732
# offered_band_E1                                     0.008842      -0.087029
# offered_band_E2                                     0.013049       0.082379
# offered_band_E3                                     0.014363       0.092652
# joining_bonus_Yes                                   0.032917       0.018093
# gender_Male                                         0.020876       0.037903
# candidate_source_Direct                             0.008092      -0.004815
# candidate_source_Employee Referral                 -0.045878      -0.028533
# lob_BFSI                                            0.119843       0.080887
# lob_CSMP                                            0.000833       0.001632
# lob_EAS                                             0.041696       0.032652
# lob_ERS                                             0.024448       0.015931
# lob_ETS                                             0.034108       0.030143
# lob_Healthcare                                      0.017921       0.011063
# lob_INFRA                                          -0.190230      -0.137354
# lob_MMS                                             0.007018       0.017857
# location_Bangalore                                  0.108741       0.022355
# location_Chennai                                    0.021079      -0.006338
# location_Cochin                                    -0.019720      -0.012477
# location_Gurgaon                                   -0.016274       0.005084
# location_Hyderabad                                  0.033918       0.029382
# location_Kolkata                                    0.016953       0.027201
# location_Mumbai                                    -0.052902      -0.057962
# location_Noida                                     -0.116962      -0.013758
# location_Others                                    -0.016741      -0.009983
# location_Pune                                      -0.002475       0.000274
#
#                                     percent_difference_ctc  rex_in_yrs  \
# duration_to_accept_offer                         -0.009395    0.113951
# notice_period                                    -0.015067    0.181786
# percent_difference_ctc                            1.000000    0.081547
# rex_in_yrs                                        0.081547    1.000000
# age                                               0.037955    0.568228
# doj_extended_Yes                                 -0.007091    0.095200
# offered_band_E1                                  -0.128058   -0.545470
# offered_band_E2                                   0.079085    0.435404
# offered_band_E3                                   0.109515    0.450314
# joining_bonus_Yes                                -0.014630    0.119621
# gender_Male                                       0.021972    0.136407
# candidate_source_Direct                          -0.000692   -0.027167
# candidate_source_Employee Referral                0.016377    0.088981
# lob_BFSI                                         -0.039160    0.021734
# lob_CSMP                                         -0.031155   -0.036525
# lob_EAS                                           0.000875    0.109671
# lob_ERS                                          -0.037500   -0.039320
# lob_ETS                                           0.013649    0.073062
# lob_Healthcare                                    0.005455    0.008369
# lob_INFRA                                         0.096417   -0.105642
# lob_MMS                                           0.003280   -0.012391
# location_Bangalore                               -0.011634    0.048713
# location_Chennai                                  0.003052   -0.017924
# location_Cochin                                  -0.023281   -0.023296
# location_Gurgaon                                 -0.005958   -0.020341
# location_Hyderabad                                0.015091    0.075979
# location_Kolkata                                 -0.027156    0.051817
# location_Mumbai                                  -0.008481   -0.008375
# location_Noida                                    0.016852   -0.063503
# location_Others                                   0.000558   -0.010462
# location_Pune                                    -0.010089    0.021880
#
#                                          age  doj_extended_Yes  \
# duration_to_accept_offer            0.020131          0.341545
# notice_period                      -0.004967          0.139732
# percent_difference_ctc              0.037955         -0.007091
# rex_in_yrs                          0.568228          0.095200
# age                                 1.000000          0.055695
# doj_extended_Yes                    0.055695          1.000000
# offered_band_E1                    -0.292662          0.007718
# offered_band_E2                     0.257871          0.032074
# offered_band_E3                     0.264929          0.009495
# joining_bonus_Yes                   0.109834          0.065666
# gender_Male                         0.113070          0.008499
# candidate_source_Direct            -0.018771          0.007839
# candidate_source_Employee Referral  0.065461         -0.005544
# lob_BFSI                            0.012753         -0.094095
# lob_CSMP                           -0.011688          0.015615
# lob_EAS                             0.098897          0.167034
# lob_ERS                            -0.073197          0.062429
# lob_ETS                             0.056644          0.076820
# lob_Healthcare                     -0.006569          0.007653
# lob_INFRA                          -0.057530         -0.137427
# lob_MMS                            -0.023072          0.005376
# location_Bangalore                  0.030261          0.035614
# location_Chennai                   -0.025053         -0.031420
# location_Cochin                    -0.007559         -0.005543
# location_Gurgaon                   -0.011663         -0.002265
# location_Hyderabad                  0.050660          0.074099
# location_Kolkata                    0.045684          0.003122
# location_Mumbai                     0.029122         -0.012388
# location_Noida                     -0.044697         -0.028325
# location_Others                     0.007948          0.017125
# location_Pune                       0.025385          0.001683
#
#                                     offered_band_E1  offered_band_E2  \
# duration_to_accept_offer                   0.008842         0.013049
# notice_period                             -0.087029         0.082379
# percent_difference_ctc                    -0.128058         0.079085
# rex_in_yrs                                -0.545470         0.435404
# age                                       -0.292662         0.257871
# doj_extended_Yes                           0.007718         0.032074
# offered_band_E1                            1.000000        -0.837219
# offered_band_E2                           -0.837219         1.000000
# offered_band_E3                           -0.310874        -0.160191
# joining_bonus_Yes                         -0.061109         0.059135
# gender_Male                               -0.084791         0.100987
# candidate_source_Direct                   -0.049042         0.011670
# candidate_source_Employee Referral        -0.109901         0.103717
# lob_BFSI                                   0.147854        -0.091494
# lob_CSMP                                   0.122754        -0.094287
# lob_EAS                                   -0.047825         0.062636
# lob_ERS                                    0.212147        -0.152403
# lob_ETS                                    0.042349        -0.031169
# lob_Healthcare                             0.041707        -0.034020
# lob_INFRA                                 -0.397175         0.256233
# lob_MMS                                    0.032064        -0.026844
# location_Bangalore                         0.089919        -0.051676
# location_Chennai                           0.093636        -0.072312
# location_Cochin                            0.015727        -0.011469
# location_Gurgaon                           0.012001         0.005746
# location_Hyderabad                        -0.040855         0.040883
# location_Kolkata                          -0.011269         0.014511
# location_Mumbai                           -0.009299         0.020901
# location_Noida                            -0.167869         0.099157
# location_Others                            0.023820        -0.018610
# location_Pune                              0.013472        -0.011529
#
#                                     offered_band_E3  joining_bonus_Yes  \
# duration_to_accept_offer                   0.014363           0.032917
# notice_period                              0.092652           0.018093
# percent_difference_ctc                     0.109515          -0.014630
# rex_in_yrs                                 0.450314           0.119621
# age                                        0.264929           0.109834
# doj_extended_Yes                           0.009495           0.065666
# offered_band_E1                           -0.310874          -0.061109
# offered_band_E2                           -0.160191           0.059135
# offered_band_E3                            1.000000           0.033509
# joining_bonus_Yes                          0.033509           1.000000
# gender_Male                                0.075528           0.022259
# candidate_source_Direct                   -0.012139          -0.001664
# candidate_source_Employee Referral         0.068888           0.006082
# lob_BFSI                                  -0.085861          -0.075519
# lob_CSMP                                  -0.056099          -0.019050
# lob_EAS                                   -0.003579           0.021884
# lob_ERS                                   -0.085098           0.061394
# lob_ETS                                    0.002186           0.063466
# lob_Healthcare                            -0.008125           0.005675
# lob_INFRA                                  0.192033          -0.122879
# lob_MMS                                   -0.009968          -0.009011
# location_Bangalore                        -0.039366           0.009330
# location_Chennai                          -0.049454          -0.008902
# location_Cochin                           -0.007277          -0.006578
# location_Gurgaon                          -0.023683           0.000969
# location_Hyderabad                         0.024923           0.022679
# location_Kolkata                           0.003078           0.022323
# location_Mumbai                           -0.006798          -0.018542
# location_Noida                             0.087106          -0.008537
# location_Others                           -0.009278          -0.008388
# location_Pune                              0.002023           0.005623
#
#                                     gender_Male  candidate_source_Direct  \
# duration_to_accept_offer               0.020876                 0.008092
# notice_period                          0.037903                -0.004815
# percent_difference_ctc                 0.021972                -0.000692
# rex_in_yrs                             0.136407                -0.027167
# age                                    0.113070                -0.018771
# doj_extended_Yes                       0.008499                 0.007839
# offered_band_E1                       -0.084791                -0.049042
# offered_band_E2                        0.100987                 0.011670
# offered_band_E3                        0.075528                -0.012139
# joining_bonus_Yes                      0.022259                -0.001664
# gender_Male                            1.000000                 0.008750
# candidate_source_Direct                0.008750                 1.000000
# candidate_source_Employee Referral    -0.033451                -0.499373
# lob_BFSI                              -0.020554                -0.031452
# lob_CSMP                              -0.026579                 0.050820
# lob_EAS                                0.013253                 0.059475
# lob_ERS                               -0.001782                -0.171660
# lob_ETS                               -0.016413                 0.086349
# lob_Healthcare                         0.013582                 0.051253
# lob_INFRA                              0.021142                 0.020041
# lob_MMS                               -0.010196                 0.027276
# location_Bangalore                     0.006486                -0.004770
# location_Chennai                      -0.001140                -0.020688
# location_Cochin                        0.013619                 0.012934
# location_Gurgaon                       0.005065                -0.036905
# location_Hyderabad                     0.005853                 0.022165
# location_Kolkata                       0.010504                 0.037764
# location_Mumbai                        0.032109                 0.046978
# location_Noida                        -0.022273                 0.004601
# location_Others                        0.017366                 0.000360
# location_Pune                         -0.015041                -0.023307
#
#                                     candidate_source_Employee Referral  \
# duration_to_accept_offer                                     -0.045878
# notice_period                                                -0.028533
# percent_difference_ctc                                        0.016377
# rex_in_yrs                                                    0.088981
# age                                                           0.065461
# doj_extended_Yes                                             -0.005544
# offered_band_E1                                              -0.109901
# offered_band_E2                                               0.103717
# offered_band_E3                                               0.068888
# joining_bonus_Yes                                             0.006082
# gender_Male                                                  -0.033451
# candidate_source_Direct                                      -0.499373
# candidate_source_Employee Referral                            1.000000
# lob_BFSI                                                     -0.064660
# lob_CSMP                                                     -0.013676
# lob_EAS                                                       0.003180
# lob_ERS                                                      -0.073176
# lob_ETS                                                      -0.018086
# lob_Healthcare                                               -0.025328
# lob_INFRA                                                     0.157870
# lob_MMS                                                      -0.011966
# location_Bangalore                                           -0.069796
# location_Chennai                                             -0.069604
# location_Cochin                                               0.005537
# location_Gurgaon                                              0.013507
# location_Hyderabad                                           -0.022779
# location_Kolkata                                              0.019335
# location_Mumbai                                               0.015382
# location_Noida                                                0.132663
# location_Others                                               0.028059
# location_Pune                                                -0.014278
#
#                                     lob_BFSI  lob_CSMP   lob_EAS   lob_ERS  \
# duration_to_accept_offer            0.119843  0.000833  0.041696  0.024448
# notice_period                       0.080887  0.001632  0.032652  0.015931
# percent_difference_ctc             -0.039160 -0.031155  0.000875 -0.037500
# rex_in_yrs                          0.021734 -0.036525  0.109671 -0.039320
# age                                 0.012753 -0.011688  0.098897 -0.073197
# doj_extended_Yes                   -0.094095  0.015615  0.167034  0.062429
# offered_band_E1                     0.147854  0.122754 -0.047825  0.212147
# offered_band_E2                    -0.091494 -0.094287  0.062636 -0.152403
# offered_band_E3                    -0.085861 -0.056099 -0.003579 -0.085098
# joining_bonus_Yes                  -0.075519 -0.019050  0.021884  0.061394
# gender_Male                        -0.020554 -0.026579  0.013253 -0.001782
# candidate_source_Direct            -0.031452  0.050820  0.059475 -0.171660
# candidate_source_Employee Referral -0.064660 -0.013676  0.003180 -0.073176
# lob_BFSI                            1.000000 -0.112422 -0.085727 -0.260472
# lob_CSMP                           -0.112422  1.000000 -0.052462 -0.159398
# lob_EAS                            -0.085727 -0.052462  1.000000 -0.121549
# lob_ERS                            -0.260472 -0.159398 -0.121549  1.000000
# lob_ETS                            -0.123640 -0.075663 -0.057697 -0.175304
# lob_Healthcare                     -0.050674 -0.031011 -0.023647 -0.071849
# lob_INFRA                          -0.291895 -0.178627 -0.136212 -0.413864
# lob_MMS                            -0.017517 -0.010720 -0.008175 -0.024837
# location_Bangalore                  0.353323 -0.079253 -0.046559 -0.004898
# location_Chennai                   -0.035317 -0.067199  0.060387  0.282214
# location_Cochin                    -0.012788 -0.007826 -0.005968 -0.018131
# location_Gurgaon                    0.056713  0.005744  0.001757 -0.068148
# location_Hyderabad                 -0.077043  0.045188  0.175205 -0.034063
# location_Kolkata                   -0.051701  0.052186 -0.024126 -0.073304
# location_Mumbai                     0.063827 -0.039249 -0.025980 -0.090936
# location_Noida                     -0.280707  0.126616 -0.075331 -0.214451
# location_Others                    -0.016306 -0.009979 -0.007609 -0.023120
# location_Pune                      -0.014537 -0.012994 -0.006715  0.068953
#
#                                      lob_ETS  lob_Healthcare  lob_INFRA  \
# duration_to_accept_offer            0.034108        0.017921  -0.190230
# notice_period                       0.030143        0.011063  -0.137354
# percent_difference_ctc              0.013649        0.005455   0.096417
# rex_in_yrs                          0.073062        0.008369  -0.105642
# age                                 0.056644       -0.006569  -0.057530
# doj_extended_Yes                    0.076820        0.007653  -0.137427
# offered_band_E1                     0.042349        0.041707  -0.397175
# offered_band_E2                    -0.031169       -0.034020   0.256233
# offered_band_E3                     0.002186       -0.008125   0.192033
# joining_bonus_Yes                   0.063466        0.005675  -0.122879
# gender_Male                        -0.016413        0.013582   0.021142
# candidate_source_Direct             0.086349        0.051253   0.020041
# candidate_source_Employee Referral -0.018086       -0.025328   0.157870
# lob_BFSI                           -0.123640       -0.050674  -0.291895
# lob_CSMP                           -0.075663       -0.031011  -0.178627
# lob_EAS                            -0.057697       -0.023647  -0.136212
# lob_ERS                            -0.175304       -0.071849  -0.413864
# lob_ETS                             1.000000       -0.034105  -0.196452
# lob_Healthcare                     -0.034105        1.000000  -0.080517
# lob_INFRA                          -0.196452       -0.080517   1.000000
# lob_MMS                            -0.011790       -0.004832  -0.027834
# location_Bangalore                  0.101214       -0.061256  -0.263170
# location_Chennai                   -0.047243        0.041126  -0.151306
# location_Cochin                    -0.008607       -0.003527   0.043810
# location_Gurgaon                   -0.027142       -0.007641   0.052458
# location_Hyderabad                  0.069521       -0.013484  -0.062615
# location_Kolkata                   -0.003195        0.001778  -0.035921
# location_Mumbai                    -0.031756       -0.011177   0.110338
# location_Noida                     -0.052215        0.027812   0.384702
# location_Others                    -0.010974       -0.004498   0.049573
# location_Pune                      -0.015399       -0.008660  -0.023643
#
#                                      lob_MMS  location_Bangalore  \
# duration_to_accept_offer            0.007018            0.108741
# notice_period                       0.017857            0.022355
# percent_difference_ctc              0.003280           -0.011634
# rex_in_yrs                         -0.012391            0.048713
# age                                -0.023072            0.030261
# doj_extended_Yes                    0.005376            0.035614
# offered_band_E1                     0.032064            0.089919
# offered_band_E2                    -0.026844           -0.051676
# offered_band_E3                    -0.009968           -0.039366
# joining_bonus_Yes                  -0.009011            0.009330
# gender_Male                        -0.010196            0.006486
# candidate_source_Direct             0.027276           -0.004770
# candidate_source_Employee Referral -0.011966           -0.069796
# lob_BFSI                           -0.017517            0.353323
# lob_CSMP                           -0.010720           -0.079253
# lob_EAS                            -0.008175           -0.046559
# lob_ERS                            -0.024837           -0.004898
# lob_ETS                            -0.011790            0.101214
# lob_Healthcare                     -0.004832           -0.061256
# lob_INFRA                          -0.027834           -0.263170
# lob_MMS                             1.000000           -0.017155
# location_Bangalore                 -0.017155            1.000000
# location_Chennai                    0.038538           -0.421484
# location_Cochin                    -0.001219           -0.017130
# location_Gurgaon                   -0.005250           -0.073748
# location_Hyderabad                 -0.008113           -0.113969
# location_Kolkata                   -0.004930           -0.069255
# location_Mumbai                    -0.006116           -0.085913
# location_Noida                     -0.015102           -0.378701
# location_Others                    -0.001555           -0.021843
# location_Pune                      -0.002994           -0.042053
#
#                                     location_Chennai  location_Cochin  \
# duration_to_accept_offer                    0.021079        -0.019720
# notice_period                              -0.006338        -0.012477
# percent_difference_ctc                      0.003052        -0.023281
# rex_in_yrs                                 -0.017924        -0.023296
# age                                        -0.025053        -0.007559
# doj_extended_Yes                           -0.031420        -0.005543
# offered_band_E1                             0.093636         0.015727
# offered_band_E2                            -0.072312        -0.011469
# offered_band_E3                            -0.049454        -0.007277
# joining_bonus_Yes                          -0.008902        -0.006578
# gender_Male                                -0.001140         0.013619
# candidate_source_Direct                    -0.020688         0.012934
# candidate_source_Employee Referral         -0.069604         0.005537
# lob_BFSI                                   -0.035317        -0.012788
# lob_CSMP                                   -0.067199        -0.007826
# lob_EAS                                     0.060387        -0.005968
# lob_ERS                                     0.282214        -0.018131
# lob_ETS                                    -0.047243        -0.008607
# lob_Healthcare                              0.041126        -0.003527
# lob_INFRA                                  -0.151306         0.043810
# lob_MMS                                     0.038538        -0.001219
# location_Bangalore                         -0.421484        -0.017130
# location_Chennai                            1.000000        -0.021903
# location_Cochin                            -0.021903         1.000000
# location_Gurgaon                           -0.094296        -0.003832
# location_Hyderabad                         -0.145724        -0.005923
# location_Kolkata                           -0.088551        -0.003599
# location_Mumbai                            -0.109851        -0.004465
# location_Noida                             -0.484218        -0.019680
# location_Others                            -0.027929        -0.001135
# location_Pune                              -0.053771        -0.002185
#
#                                     location_Gurgaon  location_Hyderabad  \
# duration_to_accept_offer                   -0.016274            0.033918
# notice_period                               0.005084            0.029382
# percent_difference_ctc                     -0.005958            0.015091
# rex_in_yrs                                 -0.020341            0.075979
# age                                        -0.011663            0.050660
# doj_extended_Yes                           -0.002265            0.074099
# offered_band_E1                             0.012001           -0.040855
# offered_band_E2                             0.005746            0.040883
# offered_band_E3                            -0.023683            0.024923
# joining_bonus_Yes                           0.000969            0.022679
# gender_Male                                 0.005065            0.005853
# candidate_source_Direct                    -0.036905            0.022165
# candidate_source_Employee Referral          0.013507           -0.022779
# lob_BFSI                                    0.056713           -0.077043
# lob_CSMP                                    0.005744            0.045188
# lob_EAS                                     0.001757            0.175205
# lob_ERS                                    -0.068148           -0.034063
# lob_ETS                                    -0.027142            0.069521
# lob_Healthcare                             -0.007641           -0.013484
# lob_INFRA                                   0.052458           -0.062615
# lob_MMS                                    -0.005250           -0.008113
# location_Bangalore                         -0.073748           -0.113969
# location_Chennai                           -0.094296           -0.145724
# location_Cochin                            -0.003832           -0.005923
# location_Gurgaon                            1.000000           -0.025498
# location_Hyderabad                         -0.025498            1.000000
# location_Kolkata                           -0.015494           -0.023944
# location_Mumbai                            -0.019221           -0.029704
# location_Noida                             -0.084724           -0.130932
# location_Others                            -0.004887           -0.007552
# location_Pune                              -0.009408           -0.014540
#
#                                     location_Kolkata  location_Mumbai  \
# duration_to_accept_offer                    0.016953        -0.052902
# notice_period                               0.027201        -0.057962
# percent_difference_ctc                     -0.027156        -0.008481
# rex_in_yrs                                  0.051817        -0.008375
# age                                         0.045684         0.029122
# doj_extended_Yes                            0.003122        -0.012388
# offered_band_E1                            -0.011269        -0.009299
# offered_band_E2                             0.014511         0.020901
# offered_band_E3                             0.003078        -0.006798
# joining_bonus_Yes                           0.022323        -0.018542
# gender_Male                                 0.010504         0.032109
# candidate_source_Direct                     0.037764         0.046978
# candidate_source_Employee Referral          0.019335         0.015382
# lob_BFSI                                   -0.051701         0.063827
# lob_CSMP                                    0.052186        -0.039249
# lob_EAS                                    -0.024126        -0.025980
# lob_ERS                                    -0.073304        -0.090936
# lob_ETS                                    -0.003195        -0.031756
# lob_Healthcare                              0.001778        -0.011177
# lob_INFRA                                  -0.035921         0.110338
# lob_MMS                                    -0.004930        -0.006116
# location_Bangalore                         -0.069255        -0.085913
# location_Chennai                           -0.088551        -0.109851
# location_Cochin                            -0.003599        -0.004465
# location_Gurgaon                           -0.015494        -0.019221
# location_Hyderabad                         -0.023944        -0.029704
# location_Kolkata                            1.000000        -0.018050
# location_Mumbai                            -0.018050         1.000000
# location_Noida                             -0.079563        -0.098700
# location_Others                            -0.004589        -0.005693
# location_Pune                              -0.008835        -0.010960
#
#                                     location_Noida  location_Others  \
# duration_to_accept_offer                 -0.116962        -0.016741
# notice_period                            -0.013758        -0.009983
# percent_difference_ctc                    0.016852         0.000558
# rex_in_yrs                               -0.063503        -0.010462
# age                                      -0.044697         0.007948
# doj_extended_Yes                         -0.028325         0.017125
# offered_band_E1                          -0.167869         0.023820
# offered_band_E2                           0.099157        -0.018610
# offered_band_E3                           0.087106        -0.009278
# joining_bonus_Yes                        -0.008537        -0.008388
# gender_Male                              -0.022273         0.017366
# candidate_source_Direct                   0.004601         0.000360
# candidate_source_Employee Referral        0.132663         0.028059
# lob_BFSI                                 -0.280707        -0.016306
# lob_CSMP                                  0.126616        -0.009979
# lob_EAS                                  -0.075331        -0.007609
# lob_ERS                                  -0.214451        -0.023120
# lob_ETS                                  -0.052215        -0.010974
# lob_Healthcare                            0.027812        -0.004498
# lob_INFRA                                 0.384702         0.049573
# lob_MMS                                  -0.015102        -0.001555
# location_Bangalore                       -0.378701        -0.021843
# location_Chennai                         -0.484218        -0.027929
# location_Cochin                          -0.019680        -0.001135
# location_Gurgaon                         -0.084724        -0.004887
# location_Hyderabad                       -0.130932        -0.007552
# location_Kolkata                         -0.079563        -0.004589
# location_Mumbai                          -0.098700        -0.005693
# location_Noida                            1.000000        -0.025094
# location_Others                          -0.025094         1.000000
# location_Pune                            -0.048313        -0.002787
#
#                                     location_Pune
# duration_to_accept_offer                -0.002475
# notice_period                            0.000274
# percent_difference_ctc                  -0.010089
# rex_in_yrs                               0.021880
# age                                      0.025385
# doj_extended_Yes                         0.001683
# offered_band_E1                          0.013472
# offered_band_E2                         -0.011529
# offered_band_E3                          0.002023
# joining_bonus_Yes                        0.005623
# gender_Male                             -0.015041
# candidate_source_Direct                 -0.023307
# candidate_source_Employee Referral      -0.014278
# lob_BFSI                                -0.014537
# lob_CSMP                                -0.012994
# lob_EAS                                 -0.006715
# lob_ERS                                  0.068953
# lob_ETS                                 -0.015399
# lob_Healthcare                          -0.008660
# lob_INFRA                               -0.023643
# lob_MMS                                 -0.002994
# location_Bangalore                      -0.042053
# location_Chennai                        -0.053771
# location_Cochin                         -0.002185
# location_Gurgaon                        -0.009408
# location_Hyderabad                      -0.014540
# location_Kolkata                        -0.008835
# location_Mumbai                         -0.010960
# location_Noida                          -0.048313
# location_Others                         -0.002787
# location_Pune                            1.000000

# %% [markdown]
# ### Train and test data split using Python
#
# The train and test split can also be done using the **sklearn module**

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split( X, Y, test_size = 0.2, random_state = 42)

# %% [markdown]
# ## Model Building: Using the **statsmodel.api**

# %%
import statsmodels.api as sm
lg_model_1 = sm.GLM(y_train, sm.add_constant(X_train),family=sm.families.Binomial()).fit()

lg_model_1.summary()
# Out:
# /Users/Rahul/anaconda3/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                 Joined   No. Observations:                 7196
# Model:                            GLM   Df Residuals:                     7164
# Model Family:                Binomial   Df Model:                           31
# Link Function:                  logit   Scale:                             1.0
# Method:                          IRLS   Log-Likelihood:                -3204.0
# Date:                Fri, 01 Jun 2018   Deviance:                       6408.0
# Time:                        23:20:41   Pearson chi2:                 7.25e+03
# No. Iterations:                    22
# ======================================================================================================
#                                          coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# const                                 -1.8090      1.225     -1.477      0.140      -4.210       0.592
# duration_to_accept_offer               0.0014      0.001      1.066      0.287      -0.001       0.004
# notice_period                         -0.0214      0.001    -14.343      0.000      -0.024      -0.018
# percent_difference_ctc                 0.0028      0.002      1.549      0.121      -0.001       0.006
# rex_in_yrs                            -0.0560      0.022     -2.545      0.011      -0.099      -0.013
# age                                    0.0466      0.010      4.556      0.000       0.027       0.067
# doj_extended_Yes                       0.1268      0.070      1.813      0.070      -0.010       0.264
# offered_band_E1                        1.1353      0.219      5.194      0.000       0.707       1.564
# offered_band_E2                        0.9676      0.238      4.058      0.000       0.500       1.435
# offered_band_E3                        1.2141      0.305      3.981      0.000       0.616       1.812
# joining_bonus_Yes                      0.1024      0.152      0.673      0.501      -0.196       0.401
# gender_Male                           -0.0767      0.087     -0.882      0.378      -0.247       0.094
# candidate_source_Direct                0.3175      0.073      4.368      0.000       0.175       0.460
# candidate_source_Employee Referral     0.7215      0.108      6.681      0.000       0.510       0.933
# lob_BFSI                               0.1448      0.152      0.952      0.341      -0.153       0.443
# lob_CSMP                               0.2829      0.176      1.607      0.108      -0.062       0.628
# lob_EAS                               -0.0887      0.191     -0.465      0.642      -0.462       0.285
# lob_ERS                                0.2334      0.143      1.632      0.103      -0.047       0.514
# lob_ETS                                0.5449      0.171      3.180      0.001       0.209       0.881
# lob_Healthcare                         0.2428      0.293      0.828      0.407      -0.332       0.817
# lob_INFRA                              0.7058      0.156      4.511      0.000       0.399       1.013
# lob_MMS                               22.6205   2.14e+04      0.001      0.999   -4.19e+04     4.2e+04
# location_Bangalore                     1.2355      1.163      1.062      0.288      -1.044       3.515
# location_Chennai                       1.2421      1.162      1.069      0.285      -1.035       3.519
# location_Cochin                       22.6016   3.24e+04      0.001      0.999   -6.35e+04    6.35e+04
# location_Gurgaon                       1.0623      1.183      0.898      0.369      -1.256       3.381
# location_Hyderabad                     1.3214      1.172      1.128      0.259      -0.975       3.618
# location_Kolkata                       1.3922      1.189      1.171      0.242      -0.939       3.723
# location_Mumbai                        1.4611      1.187      1.231      0.218      -0.865       3.787
# location_Noida                         1.5976      1.161      1.376      0.169      -0.679       3.874
# location_Others                       22.6048   2.21e+04      0.001      0.999   -4.33e+04    4.34e+04
# location_Pune                          1.5510      1.253      1.237      0.216      -0.906       4.008
# ======================================================================================================
# """

# %% [markdown]
# ## Model Approach 2:  Without dummy variable coding

# %%
import statsmodels.formula.api as smf

# %% [markdown]
# To print the name of all the models in any library

# %%
#dir(smf)

# %% [markdown]
# ### 3. Create train and test dataset
#
# #### Run a R code in python kernal
#
# To run R code from within python kernal.
#
# * use pip to install rpy2 (if not already installed). (!pip install rmagic)
# * Use conda not pip if the R installation is done using conda (!conda install -c r rpy2)
#
# The rmagic function has moved to rpy2 and thus the installation of rpy2 is needed. Once done, use the below code to load rpy2.ipython and follow with the code. YOu willl find a note on using **%load_ext rmagic** but this does not work now.
#
# #!pip install rmagic
# #!conda install -c r rpy2

# %%
# %reload_ext rpy2.ipython

# %%
from rpy2.robjects import r, pandas2ri
pandas2ri.activate()

# %% [markdown]
# #### Reserve 80% for **_training_** and 20% of **_test_**
# Create training and test dataframe using R. Pass the dataframe back to Python kernal

# %%
# %%R -i filter_df
# library(caret)
# set.seed(300)
# trainIndex <- createDataPartition(filter_df$status, p = 0.80, list = FALSE)
# train_df <- filter_df[trainIndex,]
# test_df <- filter_df[-trainIndex,]

# %%
# %R -o train_df
train_df.head()
# Out:
#   doj_extended  duration_to_accept_offer  notice_period offered_band  \
# 0          Yes                        14             30           E2
# 1           No                        18             30           E2
# 2           No                         3             45           E2
# 3           No                        26             30           E2
# 4          Yes                         1            120           E2
#
#    pecent_hike_expected_in_ctc  percent_hike_offered_in_ctc  \
# 0                       -20.79                        13.16
# 1                        50.00                       320.00
# 2                        42.84                        42.84
# 3                        42.84                        42.84
# 4                        42.59                        42.59
#
#    percent_difference_ctc joining_bonus candidate_relocate_actual  gender  \
# 0                   42.86            No                        No  Female
# 1                  180.00            No                        No    Male
# 2                    0.00            No                        No    Male
# 3                    0.00            No                        No    Male
# 4                    0.00            No                       Yes    Male
#
#     candidate_source  rex_in_yrs    lob location  age  status
# 0             Agency           7    ERS    Noida   34  Joined
# 1  Employee Referral           8  INFRA  Chennai   34  Joined
# 2             Agency           4  INFRA    Noida   27  Joined
# 3  Employee Referral           4  INFRA    Noida   34  Joined
# 4  Employee Referral           6  INFRA    Noida   34  Joined

# %%
# %R -o test_df
test_df.head()
# Out:
#    doj_extended  duration_to_accept_offer  notice_period offered_band  \
# 7           Yes                        16              0           E1
# 18           No                         1             30           E1
# 20           No                         1              0           E3
# 33           No                        24             30           E2
# 34          Yes                        10             60           E3
#
#     pecent_hike_expected_in_ctc  percent_hike_offered_in_ctc  \
# 7                        -20.00                       -20.00
# 18                       -13.42                        42.86
# 20                        42.78                        42.78
# 33                        20.48                        23.95
# 34                        25.00                        29.17
#
#     percent_difference_ctc joining_bonus candidate_relocate_actual  gender  \
# 7                     0.00            No                        No  Female
# 18                   65.00            No                        No    Male
# 20                    0.00            No                       Yes    Male
# 33                    2.88            No                        No    Male
# 34                    3.33            No                        No    Male
#
#      candidate_source  rex_in_yrs         lob location  age      status
# 7              Direct           8  Healthcare    Noida   34      Joined
# 18             Direct           1       INFRA  Gurgaon   34      Joined
# 20  Employee Referral           8       INFRA  Chennai   29      Joined
# 33             Direct           6       INFRA  Chennai   29  Not Joined
# 34  Employee Referral           6       INFRA    Noida   32      Joined

# %% [markdown]
# We can pull the specific attribute needed to build the model is another data frame. This again is more of a hygine practice to not touch the **train** and **test** data set directly.

# %%
lg_train_df = train_df.filter(['duration_to_accept_offer',
                               'notice_period',
                               'percent_difference_ctc',
                               'rex_in_yrs',
                               'age',
                               'doj_extended',
                               'offered_band',
#                               'pecent_hike_expected_in_ctc',
#                               'percent_hike_offered_in_ctc',
                               'joining_bonus',
#                               'candidate_relocate_actual',
                               'gender',
                               'candidate_source',
                               'lob',
                               'location',
                               'status'
                              ], axis = 1)

lg_test_df = test_df.filter(['duration_to_accept_offer',
                               'notice_period',
                               'percent_difference_ctc',
                               'rex_in_yrs',
                               'age',
                               'doj_extended',
                               'offered_band',
#                               'pecent_hike_expected_in_ctc',
#                               'percent_hike_offered_in_ctc',
                               'joining_bonus',
#                               'candidate_relocate_actual',
                               'gender',
                               'candidate_source',
                               'lob',
                               'location',
                               'status'
                              ], axis = 1)

lg_train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7197 entries, 0 to 8994
# Data columns (total 13 columns):
# duration_to_accept_offer    7197 non-null int32
# notice_period               7197 non-null int32
# percent_difference_ctc      7197 non-null float64
# rex_in_yrs                  7197 non-null int32
# age                         7197 non-null int32
# doj_extended                7197 non-null object
# offered_band                7197 non-null object
# joining_bonus               7197 non-null object
# gender                      7197 non-null object
# candidate_source            7197 non-null object
# lob                         7197 non-null object
# location                    7197 non-null object
# status                      7197 non-null object
# dtypes: float64(1), int32(4), object(8)
# memory usage: 674.7+ KB

# %% [markdown]
# Writing the formula with the required set of variables to be used in model building

# %%
pass_formula = 'C(status) ~ \
            duration_to_accept_offer+ \
            notice_period + \
            percent_difference_ctc + \
            rex_in_yrs + \
            age + \
            C(doj_extended) + \
            C(offered_band) + \
            C(joining_bonus) + \
            C(gender) + \
            C(candidate_source) + \
            C(lob) + \
            C(location)'

# %%
lg_model_2 = smf.glm(formula=pass_formula, data=lg_train_df,family=sm.families.Binomial()).fit()
lg_model_2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                Generalized Linear Model Regression Results
# ==========================================================================================================
# Dep. Variable:     ['C(status)[Joined]', 'C(status)[Not Joined]']   No. Observations:                 7197
# Model:                                                        GLM   Df Residuals:                     7165
# Model Family:                                            Binomial   Df Model:                           31
# Link Function:                                              logit   Scale:                             1.0
# Method:                                                      IRLS   Log-Likelihood:                -3210.4
# Date:                                            Fri, 01 Jun 2018   Deviance:                       6420.8
# Time:                                                    23:21:13   Pearson chi2:                 7.27e+03
# No. Iterations:                                                22
# ============================================================================================================
#                                                coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------
# Intercept                                   -2.2252      1.325     -1.680      0.093      -4.821       0.371
# C(doj_extended)[T.Yes]                       0.0931      0.070      1.325      0.185      -0.045       0.231
# C(offered_band)[T.E1]                        1.2289      0.213      5.770      0.000       0.811       1.646
# C(offered_band)[T.E2]                        1.0743      0.233      4.617      0.000       0.618       1.530
# C(offered_band)[T.E3]                        1.3200      0.300      4.402      0.000       0.732       1.908
# C(joining_bonus)[T.Yes]                     -0.1008      0.148     -0.680      0.496      -0.391       0.190
# C(gender)[T.Male]                           -0.1619      0.088     -1.830      0.067      -0.335       0.011
# C(candidate_source)[T.Direct]                0.3512      0.073      4.840      0.000       0.209       0.493
# C(candidate_source)[T.Employee Referral]     0.7959      0.107      7.405      0.000       0.585       1.007
# C(lob)[T.BFSI]                               0.0574      0.151      0.380      0.704      -0.239       0.354
# C(lob)[T.CSMP]                               0.0491      0.173      0.285      0.776      -0.289       0.388
# C(lob)[T.EAS]                               -0.1808      0.193     -0.938      0.348      -0.559       0.197
# C(lob)[T.ERS]                                0.1791      0.143      1.253      0.210      -0.101       0.459
# C(lob)[T.ETS]                                0.3732      0.170      2.196      0.028       0.040       0.706
# C(lob)[T.Healthcare]                         0.4782      0.314      1.523      0.128      -0.137       1.094
# C(lob)[T.INFRA]                              0.5947      0.157      3.799      0.000       0.288       0.901
# C(lob)[T.MMS]                               22.6075   2.22e+04      0.001      0.999   -4.35e+04    4.36e+04
# C(location)[T.Bangalore]                     1.6417      1.271      1.291      0.197      -0.850       4.133
# C(location)[T.Chennai]                       1.6279      1.270      1.282      0.200      -0.862       4.117
# C(location)[T.Cochin]                        1.3268      1.664      0.797      0.425      -1.935       4.589
# C(location)[T.Gurgaon]                       1.8348      1.295      1.417      0.156      -0.703       4.373
# C(location)[T.Hyderabad]                     1.6527      1.279      1.292      0.196      -0.854       4.160
# C(location)[T.Kolkata]                       1.5327      1.294      1.185      0.236      -1.003       4.069
# C(location)[T.Mumbai]                        1.8546      1.292      1.435      0.151      -0.678       4.387
# C(location)[T.Noida]                         2.0049      1.270      1.579      0.114      -0.484       4.494
# C(location)[T.Others]                       23.1172   2.11e+04      0.001      0.999   -4.14e+04    4.14e+04
# C(location)[T.Pune]                          1.7656      1.336      1.321      0.186      -0.853       4.384
# duration_to_accept_offer                     0.0025      0.001      1.885      0.059    -9.9e-05       0.005
# notice_period                               -0.0217      0.002    -14.445      0.000      -0.025      -0.019
# percent_difference_ctc                       0.0041      0.002      2.127      0.033       0.000       0.008
# rex_in_yrs                                  -0.0639      0.022     -2.917      0.004      -0.107      -0.021
# age                                          0.0498      0.010      4.882      0.000       0.030       0.070
# ============================================================================================================
# """

# %% [markdown]
# ## Find the significant variables

# %%
def get_significant_vars (modelobject):
    var_p_vals_df = pd.DataFrame(modelobject.pvalues)
    var_p_vals_df['vars'] = var_p_vals_df.index
    var_p_vals_df.columns = ['pvals', 'vars']
    return list(var_p_vals_df[var_p_vals_df.pvals <= 0.05]['vars'])

# %%
significant_vars_1 = get_significant_vars(lg_model_1)
significant_vars_1

significant_vars_2 = get_significant_vars(lg_model_2)
significant_vars_2
# Out:
# ['notice_period',
#  'rex_in_yrs',
#  'age',
#  'offered_band_E1',
#  'offered_band_E2',
#  'offered_band_E3',
#  'candidate_source_Direct',
#  'candidate_source_Employee Referral',
#  'lob_ETS',
#  'lob_INFRA']
# ['C(offered_band)[T.E1]',
#  'C(offered_band)[T.E2]',
#  'C(offered_band)[T.E3]',
#  'C(candidate_source)[T.Direct]',
#  'C(candidate_source)[T.Employee Referral]',
#  'C(lob)[T.ETS]',
#  'C(lob)[T.INFRA]',
#  'notice_period',
#  'percent_difference_ctc',
#  'rex_in_yrs',
#  'age']

# %% [markdown]
# ## Model Evaluation

# %% [markdown]
# ### 1. The prediction on train data.
# Two ways to precit the outcome on the **train set**
# > * Use **predict** function of the model object
# * Use **get_prediction** function of the model object
#
# For the model with dummy variable coding explicetely done, we need to add the constant term to the test set. For the model with dummy variable coding carried out automatically, there is no need to add the constant term to the test set.

# %% [markdown]
# Below is the output from model with dummy variable coding

# %%
train_df_predict_1 = lg_model_1.predict(sm.add_constant(X_train))
train_df_predict_1.head()

train_df_predict_2 = lg_model_1.get_prediction(sm.add_constant(X_train))
train_df_predict_2.predicted_mean[0:5]
# Out:
# 7842    0.900348
# 5268    0.850575
# 6800    0.717952
# 7146    0.601619
# 5304    0.753529
# dtype: float64
# array([0.90034791, 0.8505753 , 0.71795236, 0.60161944, 0.75352879])

# %% [markdown]
# Here is the output with the model with no dummy variable coding

# %%
train_df_predict_3 = lg_model_2.predict(sm.add_constant(lg_train_df))
train_df_predict_3.head()

train_df_predict_4 = lg_model_2.get_prediction(lg_train_df)
train_df_predict_4.predicted_mean[0:5]
# Out:
# 0    0.873291
# 1    0.953187
# 2    0.803215
# 3    0.949506
# 4    0.707400
# dtype: float64
# array([0.8732908 , 0.95318724, 0.80321483, 0.94950636, 0.70740006])

# %% [markdown]
# ### 2. The prediction on test data.
#
# The prediction can be carried out by **defining functions** as well. Below is one such instance wherein a function is defined and is used for prediction

# %%
def get_predictions ( test_class, model, test_data ):
    y_pred_df = pd.DataFrame( { 'actual': test_class,
                               'predicted_prob': model.get_prediction(sm.add_constant(test_data)).predicted_mean})
    return y_pred_df

# %% [markdown]
# Giving label to the Y column of the test set by using the dictionary data type in python. This is being done for the model which was built using dummy variable coding. It will be used to generate confusion matrix at a later time

# %%
ser = y_test
status_dict = {1:"Joined", 0:"Not Joined"}
class_test_df = ser.replace(dict(Joined=status_dict))
class_test_df.rename({'Joined': 'status'}, axis='columns', inplace=True )
class_test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1799 entries, 4622 to 8436
# Data columns (total 1 columns):
# status    1799 non-null object
# dtypes: object(1)
# memory usage: 28.1+ KB

# %%
model_1_pred_test_df = pd.DataFrame(get_predictions(class_test_df.status, lg_model_1, X_test))
model_1_pred_test_df.head()

model_2_pred_test_df = get_predictions( lg_test_df.status, lg_model_2, lg_test_df)
model_2_pred_test_df.head()
# Out:
#       actual  predicted_prob
# 4622  Joined        0.951024
# 1530  Joined        0.886797
# 8706  Joined        0.908434
# 2233  Joined        0.762933
# 676   Joined        0.920166
#         actual  predicted_prob
# 7       Joined        0.959043
# 18      Joined        0.946219
# 20      Joined        0.947216
# 33  Not Joined        0.850975
# 34      Joined        0.914335

# %%
model_1_pred_test_df['predicted'] = model_1_pred_test_df.predicted_prob.map(lambda x: 'Joined' if x > 0.5 else 'Not Joined')
model_1_pred_test_df[0:10]


model_2_pred_test_df['predicted'] = model_2_pred_test_df.predicted_prob.map(lambda x: 'Joined' if x > 0.5 else 'Not Joined') 
model_2_pred_test_df[0:10]
# Out:
#           actual  predicted_prob predicted
# 4622      Joined        0.951024    Joined
# 1530      Joined        0.886797    Joined
# 8706      Joined        0.908434    Joined
# 2233      Joined        0.762933    Joined
# 676       Joined        0.920166    Joined
# 6778      Joined        0.782541    Joined
# 2075  Not Joined        0.776997    Joined
# 6998  Not Joined        0.843907    Joined
# 8606  Not Joined        0.935025    Joined
# 7375      Joined        0.820769    Joined
#         actual  predicted_prob predicted
# 7       Joined        0.959043    Joined
# 18      Joined        0.946219    Joined
# 20      Joined        0.947216    Joined
# 33  Not Joined        0.850975    Joined
# 34      Joined        0.914335    Joined
# 37      Joined        0.916056    Joined
# 40  Not Joined        0.945117    Joined
# 44      Joined        0.967777    Joined
# 47  Not Joined        0.946150    Joined
# 50      Joined        0.832030    Joined

# %% [markdown]
# ### 3. Confusion Matrix
#
# We will built classification matrix using the **metrics** method from **sklearn** package. We will also write a custom function to build a classification matrix and use it for reporting the performance measures.
#
# #### 3a. Confusion Matrix using sklearn

# %%
from sklearn import metrics
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
print("The model 1 with dummy variable coding output: ")
confusion_matrix(class_test_df.status, model_1_pred_test_df.predicted)
model_1_report = (classification_report(class_test_df, model_1_pred_test_df.predicted))
print(model_1_report)

print("The model 2 without dummy variable coding output: ")  
confusion_matrix(lg_test_df.status, model_2_pred_test_df.predicted)
model_2_report = classification_report(lg_test_df.status, model_2_pred_test_df.predicted)
print(model_2_report)
# Out:
# The model 1 with dummy variable coding output:
# array([[1448,   11],
#        [ 331,    9]])
#              precision    recall  f1-score   support
#
#      Joined       0.81      0.99      0.89      1459
#  Not Joined       0.45      0.03      0.05       340
#
# avg / total       0.75      0.81      0.73      1799
#
# The model 2 without dummy variable coding output:
# array([[1443,   19],
#        [ 316,   20]])
#              precision    recall  f1-score   support
#
#      Joined       0.82      0.99      0.90      1462
#  Not Joined       0.51      0.06      0.11       336
#
# avg / total       0.76      0.81      0.75      1798

# %% [markdown]
# #### 3b Confusion Matrix using generic function

# %%
def draw_cm( actual, predicted ):
    plt.figure(figsize=(9,9))
    cm = metrics.confusion_matrix( actual, predicted )
    sn.heatmap(cm, annot=True,  fmt='.0f', xticklabels = ["Joined", "Not Joined"] , 
               yticklabels = ["Joined", "Not Joined"],cmap = 'Blues_r')
    plt.ylabel('Actual')
    plt.xlabel('Predicted')
    plt.title('Classification Matrix Plot', size = 15);
    plt.show()

# %% [markdown]
# The classification matrix plot as reported by **model 1**  with dummy variable coding is:

# %%
draw_cm( model_1_pred_test_df.actual, model_1_pred_test_df.predicted )

# %% [markdown]
# The classification matrix plot as reported by **model 2**  without dummy variable coding is:

# %%
draw_cm( model_2_pred_test_df.actual, model_2_pred_test_df.predicted )

# %% [markdown]
# ### 4. Performance Measure on the test set

# %%
def measure_performance (clasf_matrix):
    measure = pd.DataFrame({
                        'sensitivity': [round(clasf_matrix[0,0]/(clasf_matrix[0,0]+clasf_matrix[0,1]),2)], 
                        'specificity': [round(clasf_matrix[1,1]/(clasf_matrix[1,0]+clasf_matrix[1,1]),2)],
                        'recall': [round(clasf_matrix[0,0]/(clasf_matrix[0,0]+clasf_matrix[0,1]),2)],
                        'precision': [round(clasf_matrix[0,0]/(clasf_matrix[0,0]+clasf_matrix[1,0]),2)],
                        'overall_acc': [round((clasf_matrix[0,0]+clasf_matrix[1,1])/
                                              (clasf_matrix[0,0]+clasf_matrix[0,1]+clasf_matrix[1,0]+clasf_matrix[1,1]),2)]
                       })
    return measure

# %%
cm = metrics.confusion_matrix(model_2_pred_test_df.actual, model_2_pred_test_df.predicted)

model_2_metrics_df = pd.DataFrame(measure_performance(cm))
model_2_metrics_df

print( 'Total Accuracy sklearn: ',np.round( metrics.accuracy_score( lg_test_df.status, model_2_pred_df.predicted ), 2 ) )
# Out:
#    overall_acc  precision  recall  sensitivity  specificity
# 0         0.81       0.82    0.99         0.99         0.06
# Total Accuracy sklearn:  0.81

# %% [markdown]
# ### 5. The optimal cut-off
#
# We are going to use model 2 without dummy variable coding to select the optimal cut-off.
#
# > As an exercise, participants can change the code to find the optimal cut-off using model 1 and compare the outcome

# %% [markdown]
# #### Select the optimal cut-off value, if:
#
# > 1. Cost of Mis-classifying Not Joined as Joined is twice as costly as cost of micalssifying Joined as Not Joined
# 2. Both sensitivity and specificity are equally important
#
# The best cut-off is the one which minimizes the misclassification cost (in case of **_option 1_**) or which maximizes the Youden's Index (in case of **_Option 2_**).

# %%
lg_pred_prob_df = lg_model_2.predict(sm.add_constant(lg_train_df))
n = len(lg_train_df)

costs =  pd.DataFrame.from_items([('Joined', [0,1]), ('Not Joined', [2,0])],
                    orient='index', columns=['Joined', 'Not Joined'])

print(costs)
costs.iloc[0][1] #to refer to specific value at a given position
# Out:
#             Joined  Not Joined
# Joined           0           1
# Not Joined       2           0
# 1

# %% [markdown]
# Defining loop function to loop through float values

# %%
def frange(start, stop, step):
     s = start
     while s < stop:
         yield s
         s += step

# %%
#creating empty vectors to store the results.
cutoff = []
P11 = [] #correct classification of positive as positive
P00 = [] #correct classification of negative as negative
P10 = [] #misclassification of positive class to negative class
P01 = [] #misclassification of negative class to positive class


for i in frange(0.00, 1, 0.05):
    predicted_y = lg_pred_prob_df.map(lambda x: 'Joined' if x > i else 'Not Joined')
    tbl = metrics.confusion_matrix(lg_train_df.status, predicted_y)
    if ( i <= 1):
        j = int(20*i)
        P10.append(tbl[1,0]/(tbl[1,0] + tbl[1,1]))
        P11.append(tbl[1,1]/(tbl[1,0] + tbl[1,1]))
        P01.append(tbl[0,1]/(tbl[0,0] + tbl[0,1]))
        P00.append(tbl[0,0]/(tbl[0,0] + tbl[0,1]))
        cutoff.append(i)

d = {'cutoff':cutoff,'P10':P10,'P01': P01,'P00': P00,'P11':P11}
df_cost_table = pd.DataFrame(d, columns=['cutoff','P00','P01','P10','P11'])

# %%
df_cost_table
# Out:
#     cutoff       P00       P01       P10       P11
# 0     0.00  1.000000  0.000000  1.000000  0.000000
# 1     0.05  1.000000  0.000000  1.000000  0.000000
# 2     0.10  1.000000  0.000000  1.000000  0.000000
# 3     0.15  1.000000  0.000000  1.000000  0.000000
# 4     0.20  1.000000  0.000000  1.000000  0.000000
# 5     0.25  1.000000  0.000000  1.000000  0.000000
# 6     0.30  1.000000  0.000000  1.000000  0.000000
# 7     0.35  1.000000  0.000000  1.000000  0.000000
# 8     0.40  0.998633  0.001367  0.995542  0.004458
# 9     0.45  0.996069  0.003931  0.984398  0.015602
# 10    0.50  0.992138  0.007862  0.951709  0.048291
# 11    0.55  0.984105  0.015895  0.925706  0.074294
# 12    0.60  0.971800  0.028200  0.877415  0.122585
# 13    0.65  0.947530  0.052470  0.812036  0.187964
# 14    0.70  0.902923  0.097077  0.714710  0.285290
# 15    0.75  0.818493  0.181507  0.584695  0.415305
# 16    0.80  0.666553  0.333447  0.384844  0.615156
# 17    0.85  0.467954  0.532046  0.219911  0.780089
# 18    0.90  0.243548  0.756452  0.087667  0.912333
# 19    0.95  0.049564  0.950436  0.011887  0.988113

# %% [markdown]
# The table summarizing the optimal cut-off value:
#
# _write the cost.table into a csv file_

# %%
df_cost_table['msclaf_cost'] = df_cost_table.P01*costs.iloc[0][1]+df_cost_table.P10*costs.iloc[1][0]
df_cost_table['youden_index'] = df_cost_table.P00+df_cost_table.P11 -1
df_cost_table

#write to csv
#df_cost_table.to_csv("optimal_Cutoff_caret.csv", sep=',')
#os.getcwd()
# Out:
#     cutoff       P00       P01       P10       P11  msclaf_cost  youden_index
# 0     0.00  1.000000  0.000000  1.000000  0.000000     2.000000      0.000000
# 1     0.05  1.000000  0.000000  1.000000  0.000000     2.000000      0.000000
# 2     0.10  1.000000  0.000000  1.000000  0.000000     2.000000      0.000000
# 3     0.15  1.000000  0.000000  1.000000  0.000000     2.000000      0.000000
# 4     0.20  1.000000  0.000000  1.000000  0.000000     2.000000      0.000000
# 5     0.25  1.000000  0.000000  1.000000  0.000000     2.000000      0.000000
# 6     0.30  1.000000  0.000000  1.000000  0.000000     2.000000      0.000000
# 7     0.35  1.000000  0.000000  1.000000  0.000000     2.000000      0.000000
# 8     0.40  0.998633  0.001367  0.995542  0.004458     1.992452      0.003090
# 9     0.45  0.996069  0.003931  0.984398  0.015602     1.972727      0.011671
# 10    0.50  0.992138  0.007862  0.951709  0.048291     1.911279      0.040429
# 11    0.55  0.984105  0.015895  0.925706  0.074294     1.867306      0.058399
# 12    0.60  0.971800  0.028200  0.877415  0.122585     1.783029      0.094385
# 13    0.65  0.947530  0.052470  0.812036  0.187964     1.676541      0.135495
# 14    0.70  0.902923  0.097077  0.714710  0.285290     1.526498      0.188212
# 15    0.75  0.818493  0.181507  0.584695  0.415305     1.350898      0.233797
# 16    0.80  0.666553  0.333447  0.384844  0.615156     1.103135      0.281709
# 17    0.85  0.467954  0.532046  0.219911  0.780089     0.971867      0.248043
# 18    0.90  0.243548  0.756452  0.087667  0.912333     0.931786      0.155881
# 19    0.95  0.049564  0.950436  0.011887  0.988113     0.974210      0.037677

# %% [markdown]
# ### 5. Confusion Matrix using Optimal Cut-off
#
# The probability value along with the optimal cut-off can be used to build confusion matrix. We will use the **draw_cm** and **performance_measure** functions defined previously to report the performance of the model.

# %%
model_2_pred_test_df['predicted'] = model_2_pred_test_df.predicted_prob.map(lambda x: 'Joined' if x > 0.8 else 'Not Joined') 
model_2_pred_test_df[0:10]
# Out:
#         actual  predicted_prob predicted
# 7       Joined        0.959043    Joined
# 18      Joined        0.946219    Joined
# 20      Joined        0.947216    Joined
# 33  Not Joined        0.850975    Joined
# 34      Joined        0.914335    Joined
# 37      Joined        0.916056    Joined
# 40  Not Joined        0.945117    Joined
# 44      Joined        0.967777    Joined
# 47  Not Joined        0.946150    Joined
# 50      Joined        0.832030    Joined

# %%
draw_cm( model_2_pred_test_df.actual, model_2_pred_test_df.predicted )

# %%
cm = metrics.confusion_matrix(model_2_pred_test_df.actual, model_2_pred_test_df.predicted)

pd.DataFrame(measure_performance(cm))
# Out:
#    overall_acc  precision  recall  sensitivity  specificity
# 0         0.63       0.88    0.64         0.64         0.61

# %% [markdown]
# ### 6. ROC Plot on the test data
#
# ROCR package can be used to evaluate the model performace on the test data. The same package can also be used to get the model performace on the test data.

# %%
def draw_roc( actual, probs ):
    fpr, tpr, thresholds = metrics.roc_curve( actual, probs, drop_intermediate = False )
    auc_score = metrics.roc_auc_score( actual, probs )
    plt.figure(figsize=(6, 4))
    plt.plot( fpr, tpr, label='ROC curve (area = %0.2f)' % auc_score )
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate or [1 - True Negative Rate]')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic example')
    plt.legend(loc="lower right")
    plt.show()

    return fpr, tpr, thresholds

# %%
#fpr, tpr, thresholds = draw_roc( model_2_pred_df.actual, model_2_pred_df.predicted_prob )

# %%
#auc_score = metrics.roc_auc_score( model_2_pred_df.actual, model_2_pred_df.predicted_prob  )
#round( float( auc_score ), 2 )

# %% [markdown]
# #### End of Document
#
# ***
# ***
